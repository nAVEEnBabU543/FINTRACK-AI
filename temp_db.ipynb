# %%
import sqlite3

# %%
conn = sqlite3.connect("fintrackai.db")

# %%
cur = conn.cursor()

# %%
cur.execute('''
        CREATE TABLE USER(
            USER_ID INT PRIMARY KEY,
            USER_NAME VARCHAR(40),
            GENDER VARCHAR(20),
            EMAIL VARCHAR(100),
            PASSWORD_HASH TEXT,
            CREATED_AT DATETIME
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE VERIFICATION(
            OTP_ID INT PRIMARY KEY,
            USER_ID INT,
            EMAIL_OTP INT,
            OTP_EXP DATETIME,
            OTP_CREATION DATETIME,
            OTP_STATUS VARCHAR(30) CHECK(OTP_STATUS IN("VERIFIED","NOT VERIFIED")),
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)

        )
        ''')

# %%
cur.execute('''
        CREATE TABLE INCOMEPROFILE(
            PROFILE_ID INT PRIMARY KEY,
            USER_ID INT,
            INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
            MONTHLY_INCOME FLOAT,
            ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
            ADDITIONAL_MONTHLY_INCOME FLOAT,
            DEPENDANTS INT CHECK(DEPENDANTS<20),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
conn.commit()

# %%
import datetime

# %%
datetime.datetime.now()

# %%
cur.execute("DELETE FROM USER")
conn.commit()

# %%
import datetime
cur.execute(f'''
    INSERT INTO USER VALUES(1,"JHON","MALE","JHON@GMAIL.COM","JHVCUYW456HJKEFSADT7F875JHV3296","{datetime.datetime.now()}")
        ''')

# %%
import datetime
cur.execute(f'''
    INSERT INTO USER VALUES(2,"PAUL","MALE","PAUL@GMAIL.COM","JHVCUYWFWE873KKKFSADT7F875JHV3296","{datetime.datetime.now()}")
        ''')

# %%
conn.commit()

# %%
cur.execute("SELECT * FROM USER")
cur.fetchall()

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
conn.commit()

# %%
cur.execute("DELETE FROM VERIFICATION")
conn.commit()

# %%
conn = sqlite3.connect("fintrackai.db")
cur.execute("SELECT EMAIL,PASSWORD_HASH FROM USER")
X=cur.fetchall()
X
